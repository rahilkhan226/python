# %%
print("name:","rahil","age:",22)
# Out:
# name: rahil age: 22

# %%
print("python","java","php",sep=" |")
# Out:
# python |java |php

# %%
print("hello",end =" ")
print("world")
# Out:
# hello world

# %%
name = input("enter your name:")
print("hello,", name + "! welcome.")
# Out:
# hello, rahil khan! welcome.
