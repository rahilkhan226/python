# %%
print("hello world")
# Out:
# hello world

# %%
print("hello","python",)
# Out:
# hello python

# %%
name="python"
print("hello",name)
# Out:
# hello python

# %%
price = 12
tax = 12

print(f"total amount is {price+(price* tax/100)}")
# Out:
# total amount is 13.44

# %%
name = input("enter your name:")
print (name)
# Out:
# rahil

# %%
n1 = int(input("enter your number1:"))
n2 = int (input("enter your number2:"))
print(n1 +n2 )
# Out:
# 890
